# %%
import numpy as np

# %%
languages = np.array([
    [85, 78, 90, 88, 92],   # Python
    [80, 75, 70, 72, 74],   # Java
    [78, 82, 85, 80, 83],   # JavaScript
    [60, 65, 68, 70, 72],   # C++
    [55, 58, 60, 62, 64]    # Rust
])

# %%
print(languages.shape)
print(languages.ndim)
print(languages.size)
# Out:
# (5, 5)
# 2
# 25

# %%
n = np.mean(languages,axis=1)
n
# Out:
# array([86.6, 74.2, 81.6, 67. , 59.8])

# %%
for i in n:
    if i < 70:
        i+=70
        
n
# Out:
# array([86.6, 74.2, 81.6, 67. , 59.8])

# %%
languages
# Out:
# array([[85, 78, 90, 88, 92],
#        [80, 75, 70, 72, 74],
#        [78, 82, 85, 80, 83],
#        [60, 65, 68, 70, 72],
#        [55, 58, 60, 62, 64]])

# %%
languages[languages > 75]
# Out:
# array([85, 78, 90, 88, 92, 80, 78, 82, 85, 80, 83])

# %%
result = np.all(languages > 75, axis=1)

# %%
result
# Out:
# array([ True, False,  True, False, False])

# %%
languages[result]
# Out:
# array([[85, 78, 90, 88, 92],
#        [78, 82, 85, 80, 83]])
